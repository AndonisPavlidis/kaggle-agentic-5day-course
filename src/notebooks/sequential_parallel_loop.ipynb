# %%
from dotenv import load_dotenv
import os

from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search, AgentTool, FunctionTool
from google.genai import types

# %%
load_dotenv()
# Out:
# True

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# ### Parallel + Sequential Design Patterns

# %%
tech_researcher = Agent(
    name="TechResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
        Research the latest AI/ML trends. Include 3 key developments, the main 
        companies involved, and the potential impact. Keep the report very 
        concise (100 words).
    """,
    tools=[google_search],
    output_key="tech_research"
)

# %%
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
        Research recent medical breakthroughs. Include 3 significant advances, 
        their practical applications, and estimated timelines. Keep the report 
        concise (100 words).
    """,
    tools=[google_search],
    output_key="health_research"
)

# %%
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
        Research recent medical breakthroughs. Include 3 significant advances,
        their practical applications, and estimated timelines. Keep the report 
        concise (100 words).
    """,
    tools=[google_search],
    output_key="finance_research"
)

# %%
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
        Combine these three research findings into a single executive summary:

        **Technology Trends:**
        {tech_research}
    
        **Health Breakthroughs:**
        {health_research}
    
        **Finance Innovations:**
        {finance_research}
    
        Your summary should highlight common themes, surprising connections, and 
        the most important key takeaways from all three reports. The final summary 
        should be around 200 words.
    """,
    output_key="executive_summary",  # This will be the final output of the entire system.
)

# %%
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > ## Daily Executive Briefing: Tech, Health, and Finance
#
# **Technology:** AI democratization is rapidly advancing, making sophisticated tools accessible to more users via open-source models and cloud APIs. This trend is expected to continue its high impact throughout 2025 and beyond, fostering innovation and faster product launches. The expansion of the Internet of Things (IoT) is also a major focus, with an increasing number of connected devices transforming smart services.
#
# **Health:** Gene therapy, initially trialed in 1990, is now a recognized treatment for certain genetic diseases and blindness, with ongoing research for conditions like heart disease and cystic fibrosis. Advancements in AI are also impacting healthcare, with projections suggesting AI in financial services will double by 2029, implying similar growth in medical applications for diagnosis and treatment. Wearable devices are increasingly sophisticated, capable of predicting health issues like heart failure exacerbations within a 10-day window.
#
# **Finance:** Fintech is experiencing rapid evolution, with embedded finance becoming a backbone of digital commerce. By 2025, AI is a significant driver in financial services, projected to reach $115.4 billion, with growth expected to more than double by 2029. Blockchain technology is also transforming finance, offering enhanced security and efficiency in areas like lending and fraud screening. The integration of IoT into banking offers real-time insights for credit risk assessment, with the IoT in banking market projected to reach $30.9 billion by 2030.
# HealthResearcher > **Health:**
#
# *   **CRISPR Gene Editing Advancements:** Precise gene modification is moving beyond research into practical applications for treating genetic diseases like sickle cell anemia and cystic fibrosis. Expect wider clinical use within the next 5-10 years.
# *   **mRNA Vaccine Technology Expansion:** Building on COVID-19 success, mRNA technology is being explored for cancer vaccines and other infectious diseases. Wider applications are anticipated within 5-15 years.
# *   **AI in Diagnostics and Drug Discovery:** Artificial intelligence is significantly improving diagnostic accuracy and accelerating the discovery of new drugs. Widespread integration into clinical practice is expected within the next 3-7 years.
#
# **Technology:**
#
# *   **Agentic AI:** AI systems capable of autonomous planning and execution of workflows are rapidly developing, poised to become virtual assistants in various industries. Practical business impact is expected within 2-5 years.
# *   **Quantum Computing Progress:** Advancements in qubit stability and algorithms are paving the way for quantum computing's potential to revolutionize data processing and cryptography. Widespread practical applications are still estimated to be 5-10 years away.
#
# **Finance:**
#
# *   **AI-Driven Financial Advisors:** Advanced AI is enabling highly personalized financial planning and wealth management services. This is already impacting the market and will become more sophisticated within the next 2-5 years.
# *   **Decentralized Finance (DeFi) Evolution:** Blockchain and DeFi continue to mature, offering new models for financial services and potentially disrupting traditional banking. Broader adoption and integration are expected within 5-10 years.
# TechResearchAgent > **AI/ML Trends Briefing: Q4 2025**
#
# Three key AI/ML developments are shaping technology, health, and finance:
#
# 1.  **Generative AI and AI Agents:** Advancements in generative AI are powering sophisticated chatbots and autonomous agents capable of performing complex tasks across industries. Companies like Google (Gemini), OpenAI, and Microsoft are key players. This trend is transforming content creation, customer service, and workflow automation, enabling more personalized experiences and increased efficiency.
#
# 2.  **Multimodal AI:** AI systems are increasingly capable of understanding and processing various data types—text, images, audio, and video. Major tech companies like Google and Amazon are investing heavily in this area. Multimodal AI has a significant impact on healthcare for diagnostics and patient monitoring, and in finance for more nuanced data analysis and risk assessment.
#
# 3.  **AI in Specialized Industries (Healthcare & Finance):** AI is being tailored for specific industry needs. In healthcare, AI is driving precision medicine, improving diagnostics, and automating clinical documentation (e.g., Mount Sinai, Google Health). In finance, AI enhances fraud detection, personalizes customer experiences, and streamlines regulatory compliance (RegTech) (e.g., Bank of America, major financial institutions). This specialization is leading to more targeted, effective AI solutions.
# AggregatorAgent > ## Executive Summary: Convergence of AI, Health, and Finance Innovations
#
# Artificial Intelligence (AI) is the unifying force across technology, health, and finance, driving unprecedented advancements and cross-industry applications. Generative AI and AI agents are democratizing sophisticated tools, enabling personalized experiences and workflow automation, with significant near-term impact. This trend is amplified by multimodal AI's ability to process diverse data types, enhancing capabilities in areas like healthcare diagnostics and financial risk assessment.
#
# In healthcare, AI is accelerating drug discovery and improving diagnostics, complementing breakthroughs in gene therapy (CRISPR) and mRNA vaccine technology for treating genetic diseases and other conditions. Simultaneously, advanced AI is revolutionizing finance through personalized financial advisors and enhanced fraud detection, while blockchain and IoT integrations are reshaping banking with improved security and real-time risk assessment. The convergence of these AI-driven innovations promises to deliver more efficient, personalized, and impactful solutions across all sectors in the coming years.

# %% [markdown]
# ### Loop Design Pattern

# %%
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
        Based on the user's prompt, write the first draft of a short story 
        (around 100-150 words). Output only the story text, with no introduction 
        or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

# %%
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
        You are a constructive story critic. Review the story provided below.

        Story: {current_story}
    
         Evaluate the story's plot, characters, and pacing.
         - If the story is well-written and complete, you MUST respond with 
        the exact phrase: "APPROVED"
         - Otherwise, provide 2-3 specific, actionable suggestions for 
         improvement.
    """,
    output_key="critique",  # Stores the feedback in the state.
)

# %%
def exit_loop():
    """
    Call this function ONLY when the critique is 'APPROVED', indicating the 
    story is finished and no more changes are needed.
    """
    
    return {
        "status": "approved", "message": "Story approved. Exiting refinement loop."
    }

# %%
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
    You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function 
    and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback 
    from the critique.
    """,
    output_key="current_story",  
    tools=[
        FunctionTool(exit_loop)
    ],  
)

# %%
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, 
)

root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias traced the worn grooves of the lighthouse wall, the salt-laced air a constant companion. For twenty years, the beam had been his life, a silent promise to the churning sea. Tonight, however, a flicker from the abandoned storage room caught his eye. He pushed open the creaking door, dust motes dancing in the single shaft of moonlight. There, on a forgotten sea chest, lay a map. It wasn't parchment, but something smoother, cooler to the touch. And it glowed. Faint, ethereal lines pulsed, charting unseen islands and currents that defied any known cartography. Elias, a man of routine, felt a thrill, sharp and unexpected, pierce the quiet solitude of his life. The sea, it seemed, still held its secrets.
# CriticAgent > This is a promising start to a mystery! The atmosphere is well-established, and the discovery of the glowing map is intriguing. Here are a few suggestions for improvement:
#
# 1.  **Flesh out Elias's routine and internal state:** While you mention Elias is a "man of routine," showing a brief glimpse of that routine before the discovery would make the disruption more impactful. For instance, a sentence or two about his nightly checks, the familiar sounds of the lighthouse, or his quiet contemplation could better establish his settled life and thus highlight the "sharp and unexpected thrill."
#
# 2.  **Expand on the map's immediate effect:** The map is described as glowing and having ethereal lines. Consider adding a touch more sensory detail to Elias's interaction with it. Does the glow cast strange shadows? Does he feel any warmth or coolness emanating from it beyond its initial touch? This could enhance the sense of mystery and magic.
#
# 3.  **Hint at the map's potential purpose or origin:** The map charts "unseen islands and currents that defied any known cartography." You could add a very subtle hint that sparks Elias's curiosity further. For example, does a specific symbol on the map resemble something he's seen before, or does it seem to point towards a direction he knows well but with an inexplicable addition? This could plant the seed for the next step in the story.
# RefinerAgent > Elias traced the worn grooves of the lighthouse wall, the salt-laced air a constant companion. The rhythmic sweep of the beam overhead was a familiar lullaby, the distant sigh of waves against the rocks the only other sound. For twenty years, this stoic sentinel and its unwavering light had been his life, a silent promise to the churning sea. His nightly checks were as ingrained as the tides: the polished brass, the steady hum of the lamp, the logbook entry, always meticulous. Tonight, however, as he made his final round, a flicker from the abandoned storage room, a place usually lost to shadow and disuse, caught his eye. Curiosity, a long-dormant ember, stirred within him.
#
# He pushed open the creaking door, dust motes dancing like phantoms in the single shaft of moonlight slicing through a grimy pane. The air within was thick with the scent of brine and forgotten things. There, on a barnacle-encrusted sea chest, lay a map. It wasn't parchment, but something smoother, cooler than any paper Elias had ever touched. And it glowed. Faint, ethereal lines pulsed with an inner luminescence, charting unseen islands and currents that defied any known cartography. The light it cast was an otherworldly blue, painting the dusty confines of the room in shifting, aquatic hues, and Elias felt a strange, resonant hum emanating from it, a vibration that seemed to echo in his very bones.
#
# He reached out, his calloused fingers hovering just above the glowing surface. The lines seemed to writhe, coalescing into shapes that were both alien and strangely familiar. One cluster of islands, depicted with impossible sharpness, bore a striking resemblance to the jagged rocks off Blackwood Point, a treacherous stretch he knew intimately, yet here they were, augmented by a swirling vortex of currents and a single, star-like symbol at their heart. Elias, a man whose life had been measured in predictable increments, felt a thrill, sharp and unexpected, pierce the quiet solitude of his existence. The sea, it seemed, still held its deepest secrets, and this cryptic, luminous chart was an invitation to uncover them.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
